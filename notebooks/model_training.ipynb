# %% [markdown]
# # Sentiment Analysis Model Training
#
# This notebook demonstrates how to train the sentiment analysis model using the project scripts.

# %%
from src.train import main

if __name__ == '__main__':
    main()
